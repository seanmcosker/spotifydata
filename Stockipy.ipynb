# %%
import pandas as pd
import numpy
import scipy
import sklearn
import os

# %%
pip install spotipy --upgrade
# Out:
# Collecting spotipy
#   Using cached spotipy-2.22.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: requests>=2.25.0 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from spotipy) (2.27.1)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.3-py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.15.0 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from spotipy) (1.16.0)
# Collecting async-timeout>=4.0.2
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (3.3)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.2 redis-4.5.3 spotipy-2.22.1
# Note: you may need to restart the kernel to use updated packages.

# %%
cid='56f6a0d9a9e4403697f9932b14c55d7d'
secret='d7124eda19594d05a5d9e82aab875e9b'
SPOTIPY_REDIRECT_URI='https://example.com'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'year:2018', 'limit': 50, 'offset': 1000, 'type': 'track', 'market': None} returned 400 due to Bad request.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/spotipy/client.py:269, in Spotify._internal_call(self, method, url, payload, params)
#     264 response = self._session.request(
#     265     method, url, headers=headers, proxies=self.proxies,
#     266     timeout=self.requests_timeout, **args
#     267 )
# --> 269 response.raise_for_status()
#     270 results = response.json()
#
# File ~/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/requests/models.py:960, in Response.raise_for_status(self)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/search?q=year%3A2018&limit=50&offset=1000&type=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# /Users/seanm/Desktop/spotifydata/Stockipy.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/spotifydata/Stockipy.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> track_id = []
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/spotifydata/Stockipy.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> for i in range(0,10000,50):
# ----> <a href='vscode-notebook-cell:/Users/seanm/Desktop/spotifydata/Stockipy.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/spotifydata/Stockipy.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     for i, t in enumerate(track_results['tracks']['items']):
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/spotifydata/Stockipy.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>         artist_name.append(t['artists'][0]['name'])
#
# File ~/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/spotipy/client.py:585, in Spotify.search(self, q, limit, offset, type, market)
#     570 def search(self, q, limit=10, offset=0, type="track", market=None):
#     571     """ searches for an item
#     572
#     573         Parameters:
#    (...)
#     583                        from_token.
#     584     """
# --> 585     return self._get(
#     586         "search", q=q, limit=limit, offset=offset, type=type, market=market
#     587     )
#
# File ~/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/spotipy/client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     318 if args:
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/spotipy/client.py:291, in Spotify._internal_call(self, method, url, payload, params)
#     284         reason = None
#     286     logger.error(
#     287         'HTTP Error for %s to %s with Params: %s returned %s due to %s',
#     288         method, url, args.get("params"), response.status_code, msg
#     289     )
# --> 291     raise SpotifyException(
#     292         response.status_code,
#     293         -1,
#     294         "%s:\n %s" % (response.url, msg),
#     295         reason=reason,
#     296         headers=response.headers,
#     297     )
#     298 except requests.exceptions.RetryError as retry_error:
#     299     request = retry_error.request
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=year%3A2018&limit=50&offset=1000&type=track:
#  Bad request., reason: None

# %%
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head()
# Out:
# (1000, 4)
#      artist_name                        track_name                track_id  \
# 0  Morgan Wallen                   Whiskey Glasses  6foY66mWZN0pSRjZ408c00
# 1  Morgan Wallen                       Chasin' You  5MwynWK9s4hlyKHqhkNn4A
# 2     Juice WRLD            All Girls Are The Same  4VXIryQMWpIdGgYR4TrjT1
# 3       Lil Baby  Drip Too Hard (Lil Baby & Gunna)  78QR3Wp35dqAhFEc2qAGjE
# 4       Lil Baby                      Pure Cocaine  577YBGuskWkVDCxZrLRB4v
#
#    popularity
# 0          80
# 1          80
# 2          85
# 3          83
# 4          81

# %%
track_dataframe
# Out:
#              artist_name                        track_name  \
# 0          Morgan Wallen                   Whiskey Glasses
# 1          Morgan Wallen                       Chasin' You
# 2             Juice WRLD            All Girls Are The Same
# 3               Lil Baby  Drip Too Hard (Lil Baby & Gunna)
# 4               Lil Baby                      Pure Cocaine
# ..                   ...                               ...
# 995  La Fiera de Ojinaga            Te Vas a Acordar de Mi
# 996            Bad Bunny               Dime Si Te Acuerdas
# 997              KAROL G                         Culpables
# 998                Ozuna                         La Modelo
# 999      Greta Van Fleet            When The Curtain Falls
#
#                    track_id  popularity
# 0    6foY66mWZN0pSRjZ408c00          80
# 1    5MwynWK9s4hlyKHqhkNn4A          80
# 2    4VXIryQMWpIdGgYR4TrjT1          85
# 3    78QR3Wp35dqAhFEc2qAGjE          83
# 4    577YBGuskWkVDCxZrLRB4v          81
# ..                      ...         ...
# 995  5pdfnefsLnfBFo7gxHvqBK          61
# 996  3kG1jgWIDmjJkXhOiOmioO          69
# 997  6q8Lb50EtqNeeJXXe8mMAH          67
# 998  2SbzdGpOKlH3HIAGTWTbwU          64
# 999  2ZMI0QNoqU9fQZFirR9WpK          61
#
# [1000 rows x 4 columns]

# %%
pd.unique(track_dataframe.artist_name)
# Out:
# array(['Morgan Wallen', 'Juice WRLD', 'Lil Baby', 'The Weeknd',
#        'Rainbow Kitten Surprise', 'Kendrick Lamar', 'Luke Combs',
#        '21 Savage', 'Joji', 'Billie Eilish', '80purppp', 'TV Girl',
#        'Vacations', 'XXXTENTACION', 'The Neighbourhood', 'Metro Boomin',
#        'Post Malone', 'Kali Uchis', 'Kanye West', 'Mitski', 'Drake',
#        'Men I Trust', 'girl in red', 'Brent Faiyaz', 'Playboi Carti',
#        'Sheck Wes', 'Meek Mill', 'Travis Scott', 'Mac Miller',
#        'Summer Walker', 'Tyler Childers', 'Trippie Redd', 'Lil Peep',
#        'Khalid', 'Migos', 'A Boogie Wit da Hoodie', 'Vansire',
#        'YNW Melly', 'J. Cole', 'Marshmello', 'MGMT',
#        'Ski Mask The Slump God', 'Panic! At The Disco', 'Calvin Harris',
#        'A$AP Rocky', 'Lady Gaga', 'Alec Benjamin', 'Zedd', 'Jason Aldean',
#        'Beach Bunny', 'Polo G', 'Lauv', 'Dominic Fike',
#        '5 Seconds of Summer', 'Key Glock', 'Kodak Black', 'Cardi B',
#        'benny blanco', 'YoungBoy Never Broke Again', '03 Greedo',
#        'Imagine Dragons', 'Doja Cat', 'Tom Rosenthal', 'Lauren Daigle',
#        'Social House', 'Aminé', 'Freddie Dredd', 'Lonely God',
#        'Bad Bunny', 'Calum Scott', 'Lil Yachty', 'Mt. Joy', 'Jimin',
#        'Gucci Mane', 'Kina', '6LACK', 'Future', 'BlocBoy JB',
#        'Camila Cabello', 'Ariana Grande', 'AJR', '$uicideboy$',
#        'Charlie Puth', 'Sonder', 'Dan + Shay', 'grandson', 'Ella Mai',
#        'The Alchemist', 'Teyana Taylor', 'Jordan Davis', 'Bazzi', 'JID',
#        'Dean Lewis', 'Cory Asbury', 'Eminem', 'Roddy Ricch',
#        'Only The Family', 'Diplo', 'Nio Garcia', 'Shoreline Mafia',
#        'SadBoyProlific', 'Tyler, The Creator', 'Baby Smoove',
#        'Los Ángeles Azules', 'Leon Bridges', 'Lil Mosey', 'Anuel AA',
#        'LANCO', 'Anne-Marie', 'The Chainsmokers', 'Manchester Orchestra',
#        'Crafting Audio', 'Two Feet', 'Cody Jinks', 'Cheriimoya',
#        'Queen Naija', 'The Marías', 'Young Dolph', 'beabadoobee', 'Gunna',
#        'Clairo', 'The Plot In You', 'Vance Joy', 'Bebe Rexha', 'Jacquees',
#        'Takeoff', 'Jay Rock', 'Scotty McCreery', 'George Ezra',
#        'KIDS SEE GHOSTS', 'Novo Amor', 'Dream, Ivory', 'Masego',
#        'Rich The Kid', 'I DONT KNOW HOW BUT THEY FOUND ME',
#        'Kenny Chesney', 'Halsey', 'Ozuna', 'The 1975', 'Maroon 5',
#        'Baby Keem', 'Jeremy Zucker', 'Paulie Leparik', 'Lil Wayne',
#        'Childish Gambino', 'Nicki Minaj', 'DJ Snake', 'Twenty One Pilots',
#        'Mark Ronson', 'Strawberry Guy', 'Yung Gravy', 'Godsmack',
#        'City Girls', 'BETWEEN FRIENDS', 'Simple Plan', 'Sean Paul',
#        'lovelytheband', 'Giveon', 'Xavier Wulf', 'Kacey Musgraves',
#        'Russ', '6ix9ine', 'Gregory Alan Isakov', 'Ocie Elliott',
#        'Daniel Caesar', 'Bishop Briggs', 'Teddy Hyde', 'King Princess',
#        'Morat', 'Peach Pit', 'Au/Ra', 'TWICE',
#        'Everybody Loves an Outlaw', 'Selena Gomez', 'Casting Crowns',
#        'Current Joys', 'Famous Dex', 'Ellie Goulding', 'Shinedown', 'BTS',
#        'Nipsey Hussle', 'YBN Nahmir', 'Molchat Doma', 'The Internet',
#        'Haley Heynderickx', 'Troye Sivan', 'Lykke Li', 'Alessia Cara',
#        'ilyTOMMY', 'Still Woozy', 'Lil Xan', 'Papithbk', 'HARDY',
#        'Matt Maltese', 'BLACKPINK', 'MC L da Vinte', 'Sia', 'keshi',
#        'Cosculluela', 'NAV', 'Jubël', 'Tyga', 'ZAYN', 'YG', 'Kevin Gates',
#        'King Von', 'RL Grime', 'Blackway', 'Jordy Searcy', 'Limbo',
#        'Caamp', 'flora cash', 'Kodaline', 'Kelsea Ballerini',
#        'Maddie & Tae', 'Shawn Mendes', 'Eyedress', 'Mitchell Tenpenny',
#        'Conan Gray', "Her's", 'Shiloh Dynasty', 'Dynoro', 'Quando Rondo',
#        'Vertical Worship', 'River Whyless', 'Chris Lane',
#        'for KING & COUNTRY', 'Fatboibari', 'Aaryan Shah',
#        'Dybbukk Covers', 'J Balvin', 'ODIE', 'D. Savage', 'Aflacko',
#        'Sofia Mills', 'Bas', 'Pat Barrett', 'Mike Sherm', 'NOTD',
#        'Adam Calhoun', 'Earl Sweatshirt', 'Aldo Trujillo', 'Alina Baraz',
#        'Anson Seabra', 'Frank Ocean', 'KYSLINGO', 'Lil Uzi Vert', 'Smino',
#        'Red Velvet', 'Tate McRae', 'Comethazine', 'Logic', 'Jimmie Allen',
#        'Lil Donald', 'Riley Green', 'Dierks Bentley', 'Lil Dicky',
#        'Phoebe Bridgers', 'T3R Elemento', 'Wiz Khalifa', 'Tiësto',
#        'Lucy Dacus', 'Good Morning', 'Ed Maverick', 'Darci',
#        'Shordie Shordie', 'Curren$y', 'Justin Timberlake', 'Brett Young',
#        'Rod Wave', 'Kiana Ledé', 'SOB X RBE', 'JENNIE', 'Ghost',
#        'Hillsong Worship', 'Cavetown', 'Alan Walker', 'SiR', 'Carin Leon',
#        'KYLE', 'Sabrina Carpenter', 'Bad Wolves', 'Rae Sremmurd',
#        'Ghostemane', 'EXO', 'CORBAL', 'James Bay', 'Fleet Foxes',
#        'Maluma', 'Molina', 'Arizona Zervas', 'Clean Bandit', 'K/DA',
#        'Adriel Favela', 'Raymix', 'Duckwrth', 'Blood Orange',
#        'Pity Party (Girls Club)', 'Silk City', 'Bea Miller', 'Reddy Redd',
#        'Sasha Alex Sloan', 'The Carters', 'High Altitude Samples',
#        'League of Legends', 'Louis The Child', 'Claude Debussy',
#        'Cigarettes After Sex', 'SIX', 'Kool & The Gang', 'John Lennon',
#        'Kevin Kaarl', 'Jakob', 'Joyner Lucas', 'James Arthur', 'flipturn',
#        'Lil Gnar', 'NEFFEX', 'Brytiago', 'UMI', 'Ryan Caraveo', 'NF',
#        'ScHoolboy Q', 'Verzache', 'DJ Luian', 'Cuco', '88rising',
#        'Greta Van Fleet', 'iamjakehill', 'Wallows', 'Fuerza Regida',
#        'Devin Dawson', 'SHRK', 'Yung Bleu', 'Ruel', 'Ice Nine Kills',
#        'Alameños de la Sierra', 'Pedro Capó', 'Sanctus Real',
#        'Five Finger Death Punch', 'JayDaYoungan', 'Joey Purp', 'Saweetie',
#        'Kendo Kaponi', 'Kina Grannis', "Jack Stauber's Micropop",
#        'ShooterGang Kony', 'JPEGMAFIA', 'Princess Chelsea', 'iKON',
#        'Kygo', 'Nathaniel Rateliff & The Night Sweats', 'LANY',
#        'Lake Street Dive', 'boygenius', 'Denzel Curry', 'SHAED',
#        'Chayín Rubio', 'I AM THEY', 'MemoTheMafioso', 'El de La Guitarra',
#        'Breaking Benjamin', 'Blueface', 'Teqkoi', 'Quavo',
#        'Young the Giant', 'Pouya', 'Surfaces', 'Grupo Firme',
#        'Phil Wickham', 'Megan Thee Stallion', 'Mackned', 'BlackMayo',
#        'Max Richter', 'Trevor Daniel', 'Ashes To Amber',
#        'Herencia de Patrones', 'A$AP ANT', 'itssvd', '¿Téo?', 'Burna Boy',
#        'Omar Apollo', 'Poppy', 'boy pablo', 'Sure Sure', 'Cautious Clay',
#        'Jelly Roll', 'FISHER', "Why Don't We", 'Kensuke Ushio',
#        'Cole Swindell', 'Lewis Capaldi', 'Ashnikko', 'MO3',
#        'Trinidad Cardona', 'demxntia', 'Isak Danielson', 'Fall Out Boy',
#        'Bhad Bhabie', 'Banda MS de Sergio Lizárraga', 'Andy Mineo',
#        'Unknown Mortal Orchestra', 'Maxo', 'Kochetkovv', 'Becky G',
#        'David Lee Murphy', 'Wisin & Yandel', 'Bryant Myers',
#        'The Happy Fits', 'Whethan', 'lofi.samurai', 'Hozier',
#        'Car Seat Headrest', 'Janelle Monáe', 'Gorillaz',
#        'Earth, Wind & Fire', 'EVAN GIIA', 'Baulm.', 'La Fiera de Ojinaga',
#        'Dijon', 'INZO', 'IDK', 'El Alfa', 'Lukas Graham',
#        'Disney Peaceful Piano', 'Teedra Moses', 'Rudimental', 'Ari Afsar',
#        'Piso 21', 'Jonas Blue', 'Polyphia', 'Ellise', 'Morgan Evans',
#        'Sebastian Yatra', 'DaBaby', '90sFlav', 'Lenin Ramírez',
#        'Eli Young Band', 'Julia Michaels',
#        'Los Plebes del Rancho de Ariel Camacho', 'Taylor Swift',
#        'Money Man', 'Witt Lowry', 'Nico Collins', 'Vinny West',
#        'Layton Greene', 'Ray LaMontagne', 'Parcels', 'Three Days Grace',
#        'Shabazz PBG', 'Dua Lipa', 'Briston Maroney', 'Daddy Yankee',
#        'Rodney Atkins', 'Lil Skies', 'Fredo Bang', 'Chris Lake',
#        'KAROL G'], dtype=object)
