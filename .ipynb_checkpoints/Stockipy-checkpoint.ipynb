# %%
import pandas as pd
import numpy
import scipy
import sklearn
import os

# %%
#pip install spotipy --upgrade

# %%
cid='56f6a0d9a9e4403697f9932b14c55d7d'
secret='d7124eda19594d05a5d9e82aab875e9b'
SPOTIPY_REDIRECT_URI='https://example.com'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'year:2018', 'limit': 50, 'offset': 1000, 'type': 'track', 'market': None} returned 400 due to Bad request.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     268
# --> 269             response.raise_for_status()
#     270             results = response.json()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/search?q=year%3A2018&limit=50&offset=1000&type=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# /var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/ipykernel_72997/921199886.py in <module>
#       4 track_id = []
#       5 for i in range(0,10000,50):
# ----> 6     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#       7     for i, t in enumerate(track_results['tracks']['items']):
#       8         artist_name.append(t['artists'][0]['name'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     583                            from_token.
#     584         """
# --> 585         return self._get(
#     586             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     587         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# --> 321         return self._internal_call("GET", url, payload, kwargs)
#     322
#     323     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     289             )
#     290
# --> 291             raise SpotifyException(
#     292                 response.status_code,
#     293                 -1,
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=year%3A2018&limit=50&offset=1000&type=track:
#  Bad request., reason: None

# %%
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head()
# Out:
# (1000, 4)
#      artist_name                        track_name                track_id  \
# 0  Morgan Wallen                   Whiskey Glasses  6foY66mWZN0pSRjZ408c00
# 1  Morgan Wallen                       Chasin' You  5MwynWK9s4hlyKHqhkNn4A
# 2     Juice WRLD            All Girls Are The Same  4VXIryQMWpIdGgYR4TrjT1
# 3     The Weeknd                 I Was Never There  1cKHdTo9u0ZymJdPGSh6nq
# 4       Lil Baby  Drip Too Hard (Lil Baby & Gunna)  78QR3Wp35dqAhFEc2qAGjE
#
#    popularity
# 0          79
# 1          79
# 2          84
# 3          87
# 4          82

# %%
track_dataframe
# Out:
#        artist_name                        track_name                track_id  \
# 0    Morgan Wallen                   Whiskey Glasses  6foY66mWZN0pSRjZ408c00
# 1    Morgan Wallen                       Chasin' You  5MwynWK9s4hlyKHqhkNn4A
# 2       Juice WRLD            All Girls Are The Same  4VXIryQMWpIdGgYR4TrjT1
# 3       The Weeknd                 I Was Never There  1cKHdTo9u0ZymJdPGSh6nq
# 4         Lil Baby  Drip Too Hard (Lil Baby & Gunna)  78QR3Wp35dqAhFEc2qAGjE
# ..             ...                               ...                     ...
# 995     Kanye West                       No Mistakes  35KV2Nuib6jPMVN00O8iba
# 996           Nova                           Whitley  3NSRowkfL0rYE8S6dfT2G0
# 997          Arlie                       didya think  4HOg84QsolNLzNp08qZ3sX
# 998  Rodney Atkins          Caught Up In The Country  2BgunkkepMPFpArQj1Dx5s
# 999         Clairo                            Heaven  4XYo3W8U6IY42EbB01rnR4
#
#      popularity
# 0            79
# 1            79
# 2            84
# 3            87
# 4            82
# ..          ...
# 995          60
# 996          63
# 997          57
# 998          59
# 999          58
#
# [1000 rows x 4 columns]
